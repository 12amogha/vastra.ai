# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import joblib

def preprocess_influencer_data(data):
    numerical_features = ['followers', 'engagement_metrics', 'follower_growth_rate']
    scaler = StandardScaler()
    data[numerical_features] = scaler.fit_transform(data[numerical_features])
    return data, scaler

def calculate_match_score(row, trend_params):
    match_score = 0
    for key, value in trend_params.items():
        if key in row and row[key] == value:
            match_score += 1
    return match_score

def get_top_influencers(influencer_data, predictions, scaler, top_n=5):
    numerical_features = ['followers', 'engagement_metrics', 'follower_growth_rate']
    influencer_data[numerical_features] = scaler.inverse_transform(influencer_data[numerical_features])

    influencer_data['match_score'] = influencer_data.apply(lambda row: calculate_match_score(row, predictions), axis=1)

    score_weights = {
        'impact_score': 0.70,
        'brand_fit_score': 0.30
    }

    influencer_data['final_score'] = (
        influencer_data['match_score'] +
        score_weights['impact_score'] * influencer_data['impact_score'] +
        score_weights['brand_fit_score'] * influencer_data['brand_fit_score']
    )

    top_influencers = influencer_data.sort_values(by='final_score', ascending=False)
    
    output_columns = ['influencer_id', 'gender', 'platform', 'link', 'followers', 'public_perception', 
                      'engagement_metrics', 'follower_locations', 'follower_growth_rate', 'style', 
                      'past_collab', 'age_range', 'impact_score', 'brand_fit_score', 'final_score']
    
    return top_influencers[output_columns]

# Load influencer data and scaler
influencer_data = joblib.load('influencer_data_processed.pkl')
scaler = joblib.load('influencer_data_scaler.pkl')

# Load the trained models for trend identification
loaded_models = joblib.load('fashion_trend_models.pkl')

# Load the function to get top influencers
#get_top_influencers = joblib.load('influencer_recommender_function.pkl')

# Mapping dictionaries for categorical values
mappings = {
    'BrandName': {1: 'Allen Solly', 2: 'Levi\'s', 3: 'Adidas', 4: 'Gucci', 5: 'H&M', 6: 'Puma', 7: 'Nike', 8: 'Zara'},
    'Category': {1: 'Clothing', 2: 'Footwear', 3: 'Accessories'},
    'Individual_Category': {1: 'Jackets', 2: 'T-Shirts', 3: 'Boots', 4: 'Sweaters', 5: 'Hats', 6: 'Sweatshirts'},
    'Category_by_Gender': {1: 'Women', 2: 'Men', 3: 'Unisex'},
    'PrimaryColor': {1: 'Black', 2: 'White', 3: 'Blue', 4: 'Red', 5: 'Pink', 6: 'Yellow', 7: 'Green', 8: 'Purple', 9: 'Brown', 10: 'Orange'},
    'Size': {1: 'XS', 2: 'S', 3: 'M', 4: 'L', 5: 'XL', 6: 'XXL'},
    'Age Range': {1: '18-24', 2: '25-34', 3: '35-44'},
    'Material': {1: 'Wool', 2: 'Cotton', 3: 'Denim', 4: 'Leather', 5: 'Polyester'},
    'Pattern': {1: 'Solid', 2: 'Printed', 3: 'Floral', 4: 'Polka Dot', 5: 'Striped'},
    'Style': {1: 'Western Wear', 2: 'Casual Wear', 3: 'Sports and Active Wear', 4: 'Party Wear', 5: 'Minimalist Fashion', 6: 'Hiking', 7: 'Urban Fashion', 8: 'Streetwear'},
    'Sub-Style': {1: 'Regular Fit', 2: 'Crew Neck', 3: 'Windbreaker', 4: 'Heeled', 5: 'Loose Fit', 6: 'Fedora', 7: 'Hooded', 8: 'Hiking', 9: 'Bomber'}
}

geographic_location_mapping = {
    'Bangalore': 1,
    'Mumbai': 2,
    'Ahmedabad': 3,
    'Delhi': 4,
    'Jaipur': 5,
    'Pune': 6,
    'Hyderabad': 7,
    'Kolkata': 8,
    'Chennai': 9,
    'Chandigarh': 10
}

def predict_and_recommend(year, month_str, geographic_location_str):
    month_mapping = {
        'January': 1, 'February': 2, 'March': 3, 'April': 4, 'May': 5,
        'June': 6, 'July': 7, 'August': 8, 'September': 9, 'October': 10,
        'November': 11, 'December': 12
    }
    
    # Validate and convert user input
    try:
        month_int = month_mapping[month_str.title()]
        geographic_location_int = geographic_location_mapping[geographic_location_str.title()]
    except KeyError:
        print("Invalid Month or Geographic Location entered.")
        return
    
    # Prepare input data for prediction
    new_data = pd.DataFrame({
        'Year': [int(year)],
        'Month': [month_int],
        'Geographic Location': [geographic_location_int]
    })
    
    # Ensure all required columns are present
    all_columns = ['Year', 'Month', 'Geographic Location']
    for col in all_columns:
        if col not in new_data.columns:
            new_data[col] = 0
    
    new_data = new_data[all_columns]
    
    # Perform predictions using loaded trend identification models
    predictions = {}
    for target, pipeline in loaded_models.items():
        prediction = pipeline.predict(new_data)[0]
        predictions[target] = prediction
    
   
    rounded_predictions = {}
    for target, pred in predictions.items():
        if target in mappings:
            if isinstance(pred, np.float64):
                if target == 'Sales Data (units)':  
                    pred = int(np.round(pred))  
                else:
                    pred = np.round(pred)  
            mapped_value = mappings[target].get(pred, f'Unknown ({pred})')
            rounded_predictions[target] = mapped_value
        else:
            rounded_predictions[target] =int( pred) 
    
    
    # Display predicted fashion trends
    print(rounded_predictions) 
    print(f"\nEmerging Fashion-Trend Prediction for Year : {year}, Month : {month_str},  Geographic Location : {geographic_location_str}:")
    for key, value in rounded_predictions.items():
        print(f"{key} : {value}")
    
    # Get top influencers based on predictions
    top_influencers = get_top_influencers(influencer_data, rounded_predictions, scaler)
    
    # Display top influencers
    print("\nTop Influencers:")
    print(top_influencers)

# Example usage:
year = input("Enter the Year: ")
month_str = input("Enter the Month (Name): ")
geographic_location_str = input("Enter the Geographic Location (City): ")

predict_and_recommend(year, month_str, geographic_location_str)

#make top_influencers and rounded_predictions json as a response
# Out:
# {'BrandName': 'Gucci', 'Category': 'Footwear', 'Individual_Category': 'Sweaters', 'Category_by_Gender': 'Men', 'Sales Data (units)': 249, 'PrimaryColor': 'Yellow', 'Size': 'L', 'Age Range': '25-34', 'Material': 'Denim', 'Pattern': 'Printed', 'Style': 'Minimalist Fashion', 'Sub-Style': 'Loose Fit'}
#
# Emerging Fashion-Trend Prediction for Year : 2024, Month : june,  Geographic Location : bangalore:
# BrandName : Gucci
# Category : Footwear
# Individual_Category : Sweaters
# Category_by_Gender : Men
# Sales Data (units) : 249
# PrimaryColor : Yellow
# Size : L
# Age Range : 25-34
# Material : Denim
# Pattern : Printed
# Style : Minimalist Fashion
# Sub-Style : Loose Fit
#
# Top Influencers:
#     influencer_id  gender   platform  \
# 2              49    Male  Instagram
# 0               5    Male  Instagram
# 1              23    Male  Instagram
# 13             27    Male  Instagram
# 16             39    Male  Instagram
# 4              33    Male  Instagram
# 8              35    Male  Instagram
# 5              15    Male  Instagram
# 36             32  Female  Instagram
# 14             41    Male  Instagram
# 10             43    Male  Instagram
# 11             11    Male  Instagram
# 25             40  Female  Instagram
# 34             30  Female  Instagram
# 15             37    Male  Instagram
# 7              19    Male  Instagram
# 19              3    Male  Instagram
# 9               1    Male  Instagram
# 18             45    Male  Instagram
# 21             13    Male  Instagram
# 33             22  Female  Instagram
# 27              6  Female  Instagram
# 37             44  Female  Instagram
# 3              47    Male  Instagram
# 17             21    Male  Instagram
# 6              17    Male  Instagram
# 43             16  Female  Instagram
# 42             18  Female  Instagram
# 46              8  Female  Instagram
# 40             46  Female  Instagram
# 28             36  Female  Instagram
# 31             34  Female  Instagram
# 38             20  Female  Instagram
# 23             29    Male  Instagram
# 22             25    Male  Instagram
# 26             24  Female  Instagram
# 44             12  Female  Instagram
# 30             14  Female  Instagram
# 41             48  Female  Instagram
# 49              2  Female  Instagram
# 29             10  Female  Instagram
# 12              9    Male  Instagram
# 20             31    Male  Instagram
# 45             38  Female  Instagram
# 48             26  Female  Instagram
# 47              4  Female  Instagram
# 32             42  Female  Instagram
# 39             28  Female  Instagram
# 35             50  Female  Instagram
# 24              7    Male  Instagram
#
#                                          link  followers public_perception  \
# 2         https://www.instagram.com/ajaymehra   876365.0   mostly positive
# 0        https://www.instagram.com/arjunverma   632767.0           neutral
# 1      https://www.instagram.com/harshvardhan   870864.0   mostly positive
# 13      https://www.instagram.com/sureshraina  1207774.0   mostly positive
# 16       https://www.instagram.com/akashpatel  1104240.0   mostly positive
# 4       https://www.instagram.com/naveenkumar  1286395.0   mostly positive
# 8    https://www.instagram.com/abhishekpandey  1119791.0   mostly positive
# 5      https://www.instagram.com/adityakapoor  1160901.0          positive
# 36      https://www.instagram.com/sakshiarora  1352023.0          positive
# 14     https://www.instagram.com/prateeksingh  1311955.0           neutral
# 10      https://www.instagram.com/gauravrathi   324553.0   mostly positive
# 11        https://www.instagram.com/amitpatel   984971.0          positive
# 25     https://www.instagram.com/pallavijoshi  1158210.0           neutral
# 34        https://www.instagram.com/anjalirao   691733.0   mostly positive
# 15       https://www.instagram.com/sumitverma   854495.0          negative
# 7         https://www.instagram.com/rajeshier   708014.0   mostly negative
# 19      https://www.instagram.com/rahulsharma  1100055.0          negative
# 9       https://www.instagram.com/deepakkumar   449735.0           neutral
# 18      https://www.instagram.com/rajatsharma   907049.0           neutral
# 21      https://www.instagram.com/vikramsingh   802915.0           neutral
# 33     https://www.instagram.com/mitalibhatia   422699.0   mostly positive
# 27       https://www.instagram.com/kavyamehta   858810.0           neutral
# 37       https://www.instagram.com/sonalpatel   576323.0   mostly positive
# 3      https://www.instagram.com/mohitagarwal   517649.0   mostly negative
# 17  https://www.instagram.com/aakashchoudhary   692113.0           neutral
# 6         https://www.instagram.com/ravidubey   107287.0          positive
# 43        https://www.instagram.com/sanyajain   615584.0   mostly positive
# 42    https://www.instagram.com/nehachaudhary  1508010.0          positive
# 46      https://www.instagram.com/nishasharma  1173092.0           neutral
# 40        https://www.instagram.com/aishakhan   993157.0           neutral
# 28      https://www.instagram.com/tanyasharma   314645.0   mostly negative
# 31       https://www.instagram.com/radhikaroy  1181921.0          positive
# 38       https://www.instagram.com/snehareddy  1339424.0   mostly negative
# 23       https://www.instagram.com/yashthakur   142186.0   mostly positive
# 22         https://www.instagram.com/amanjain   787752.0          negative
# 26      https://www.instagram.com/simranarora   373381.0           neutral
# 44        https://www.instagram.com/poojanair   865574.0   mostly negative
# 30        https://www.instagram.com/ritikaroy   660945.0          positive
# 41        https://www.instagram.com/nidhisoni   140032.0   mostly positive
# 49      https://www.instagram.com/ananyasingh   584978.0   mostly positive
# 29    https://www.instagram.com/ishitaagarwal   641176.0          positive
# 12       https://www.instagram.com/sahiljoshi    47440.0          positive
# 20       https://www.instagram.com/karanbhatt   273281.0          positive
# 45       https://www.instagram.com/meghasingh   525217.0           neutral
# 48      https://www.instagram.com/bhavyamehta  1050196.0          positive
# 47       https://www.instagram.com/priyagupta  1000377.0   mostly negative
# 32      https://www.instagram.com/khushiverma   342322.0   mostly negative
# 39        https://www.instagram.com/ankitadas   741261.0          positive
# 35       https://www.instagram.com/swatigupta   265610.0          positive
# 24       https://www.instagram.com/rohitsingh    10000.0          positive
#
#     engagement_metrics                             follower_locations  \
# 2             114355.0                      ['Chandigarh', 'Chennai']
# 0              81341.0                        ['Jaipur', 'Hyderabad']
# 1              49349.0                                     ['Jaipur']
# 13            477994.0                           ['Kolkata', 'Delhi']
# 16            573027.0                          ['Mumbai', 'Chennai']
# 4             157413.0                         ['Delhi', 'Bangalore']
# 8             173062.0                       ['Hyderabad', 'Kolkata']
# 5             295379.0                ['Pune', 'Ahmedabad', 'Mumbai']
# 36            578680.0                              ['Delhi', 'Pune']
# 14            147848.0            ['Delhi', 'Bangalore', 'Ahmedabad']
# 10             82944.0             ['Kolkata', 'Mumbai', 'Bangalore']
# 11            120861.0                ['Delhi', 'Chennai', 'Kolkata']
# 25             15618.0         ['Hyderabad', 'Chandigarh', 'Kolkata']
# 34            182791.0              ['Chennai', 'Delhi', 'Bangalore']
# 15            238583.0                              ['Delhi', 'Pune']
# 7             222523.0             ['Jaipur', 'Chennai', 'Hyderabad']
# 19            407836.0                                  ['Hyderabad']
# 9              49858.0                     ['Ahmedabad', 'Hyderabad']
# 18             58722.0            ['Chennai', 'Mumbai', 'Chandigarh']
# 21            165541.0                          ['Pune', 'Ahmedabad']
# 33            229628.0                     ['Hyderabad', 'Ahmedabad']
# 27            236629.0  ['Kolkata', 'Chennai', 'Hyderabad', 'Jaipur']
# 37            206442.0                                    ['Chennai']
# 3              86597.0      ['Pune', 'Bangalore', 'Jaipur', 'Mumbai']
# 17             89973.0                     ['Hyderabad', 'Bangalore']
# 6              38371.0                                    ['Kolkata']
# 43            140510.0                          ['Mumbai', 'Kolkata']
# 42            201291.0                         ['Kolkata', 'Chennai']
# 46            131413.0                     ['Hyderabad', 'Bangalore']
# 40            204215.0             ['Hyderabad', 'Pune', 'Ahmedabad']
# 28            283521.0                    ['Chandigarh', 'Hyderabad']
# 31             49999.0                       ['Jaipur', 'Chandigarh']
# 38            138691.0                                    ['Chennai']
# 23             12776.0                             ['Mumbai', 'Pune']
# 22            108358.0                                  ['Hyderabad']
# 26            113160.0            ['Jaipur', 'Chandigarh', 'Chennai']
# 44            254973.0                            ['Mumbai', 'Delhi']
# 30            125474.0                            ['Pune', 'Kolkata']
# 41             29387.0                       ['Kolkata', 'Ahmedabad']
# 49            132271.0                                  ['Hyderabad']
# 29             74379.0                ['Jaipur', 'Pune', 'Hyderabad']
# 12             13617.0                        ['Jaipur', 'Hyderabad']
# 20             82716.0                                 ['Chandigarh']
# 45             29346.0                                       ['Pune']
# 48             44176.0                                      ['Delhi']
# 47             85011.0                                      ['Delhi']
# 32             44241.0                  ['Delhi', 'Mumbai', 'Jaipur']
# 39             10613.0                                    ['Chennai']
# 35             85921.0                        ['Ahmedabad', 'Jaipur']
# 24              1129.0                                    ['Chennai']
#
#     follower_growth_rate                                              style  \
# 2               0.350717  ['Streetwear', 'Casual Wear', 'Sports and Acti...
# 0               0.426004  ['Western Wear', 'Casual Wear', 'Streetwear', ...
# 1               0.147600  ['Casual Wear', 'Streetwear', 'Sports and Acti...
# 13              0.212224                     ['Party Wear', 'Western Wear']
# 16              0.261062                ['Formal Wear', 'Business Formals']
# 4               0.209728         ['Minimalist Fashion', 'Business Formals']
# 8               0.643542                     ['Western Wear', 'Streetwear']
# 5               0.165571           ['Athleisure', 'Sports and Active Wear']
# 36              0.464894                   ['Gothic Fashion', 'Streetwear']
# 14              0.351365  ['Maternity', 'Ethnic Casuals', 'Traditional W...
# 10              0.611496              ['Minimalist Fashion', 'Formal Wear']
# 11              0.451195              ['Urban Fashion', 'Business Formals']
# 25              0.592917       ['Workout Gear', 'Athleisure', 'Streetwear']
# 34              0.372754                   ['Gothic Fashion', 'Streetwear']
# 15              0.302703  ['Ethnic Casuals', 'Traditional Wear', 'Indian...
# 7               0.498356                     ['Workout Gear', 'Athleisure']
# 19              0.075015                               ['Traditional Wear']
# 9               0.260711                   ['Formal Wear', 'Urban Fashion']
# 18              0.409667  ['Retro Style', 'Bohemian Style', 'Vintage Clo...
# 21              0.603211  ['Urban Fashion', 'Formal Wear', 'Business For...
# 33              0.626004              ['Minimalist Fashion', 'Formal Wear']
# 27             -0.089302                                 ['Ethnic Casuals']
# 37              0.359189  ['Business Formals', 'Formal Wear', 'Urban Fas...
# 3               0.411160  ['Indian and Fusion Wear', 'Ethnic Casuals', '...
# 17              1.000000             ['Ethnic Casuals', 'Traditional Wear']
# 6               0.230306                       ['Athleisure', 'Streetwear']
# 43              0.582603                     ['Party Wear', 'Western Wear']
# 42              0.542933                ['Vintage Clothing', 'Retro Style']
# 46              0.020114  ['Bohemian Style', 'Retro Style', 'Vintage Clo...
# 40              0.463905                                     ['Party Wear']
# 28              0.773104                   ['Formal Wear', 'Urban Fashion']
# 31              0.174936  ['Retro Style', 'Vintage Clothing', 'Bohemian ...
# 38              0.645213              ['Minimalist Fashion', 'Formal Wear']
# 23              0.289925                                 ['Gothic Fashion']
# 22              0.305572                                      ['Beachwear']
# 26              0.136509                                   ['Western Wear']
# 44              0.877290                ['Retro Style', 'Vintage Clothing']
# 30              0.394452                                   ['Workout Gear']
# 41              0.253241  ['Indian and Fusion Wear', 'Traditional Wear',...
# 49              0.038901                      ['Streetwear', 'Casual Wear']
# 29              0.260432  ['Indian and Fusion Wear', 'Traditional Wear',...
# 12              0.269142  ['Formal Wear', 'Business Formals', 'Minimalis...
# 20              0.331118                         ['Indian and Fusion Wear']
# 45              0.427684                   ['Urban Fashion', 'Formal Wear']
# 48              0.411126                ['Retro Style', 'Vintage Clothing']
# 47              0.269973                                      ['Beachwear']
# 32              0.180816                                  ['Urban Fashion']
# 39              0.567995     ['Indian and Fusion Wear', 'Traditional Wear']
# 35              0.194577                ['Retro Style', 'Vintage Clothing']
# 24              0.475799                                 ['Ethnic Casuals']
#
#                                           past_collab age_range  impact_score  \
# 2   ['Under Armour', 'H&M', 'Puma', 'Nike', 'Zara'...     18-24      1.269090
# 0   ['Zara', 'Under Armour', 'Adidas', "Levi's", '...     25-34      1.644540
# 1   ['Reebok', 'Nike', 'Adidas', 'H&M', 'Puma', "L...     25-34      1.332589
# 13                        ["Levi's", 'Gucci', 'Zara']     18-24      0.767010
# 16                                  ['Zara', 'Gucci']     18-24      0.665268
# 4          ['Gucci', 'Zara', "Levi's", 'Allen Solly']     18-24      0.934725
# 8                  ['Gucci', "Levi's", 'Zara', 'H&M']     18-24      0.880517
# 5                ['Reebok', 'Under Armour', 'Adidas']     25-34      0.932372
# 36                          ["Levi's", 'Zara', 'H&M']     18-24      0.079744
# 14                                            ['H&M']     25-34      0.691488
# 10                   ['Allen Solly', 'Zara', 'Gucci']     18-24      0.828190
# 11                        ["Levi's", 'Zara', 'Gucci']     18-24      0.817541
# 25                ['Nike', "Levi's", 'Adidas', 'H&M']     18-24      0.274867
# 34                          ['H&M', "Levi's", 'Zara']     25-34      0.115044
# 15                            ['Allen Solly', 'Zara']     18-24      0.683291
# 7                                            ['Puma']     35-44      0.903957
# 19                                    ['Allen Solly']     25-34      0.619465
# 9          ['Allen Solly', 'Zara', 'Gucci', "Levi's"]     18-24      0.874462
# 18                                           ['Zara']     18-24      0.636595
# 21                                           ['Zara']     18-24      0.570645
# 33                  ['Zara', "Levi's", 'Allen Solly']     35-44      0.123428
# 27                                           ['Zara']     18-24      0.244324
# 37                  ['Zara', 'Allen Solly', "Levi's"]     18-24      0.043856
# 3                                     ['Allen Solly']     35-44      0.983286
# 17                                           ['Zara']     25-34      0.642840
# 6   ['H&M', 'Puma', 'Adidas', 'Under Armour', 'Nik...     18-24      0.912765
# 43                                    ['H&M', 'Zara']     18-24     -0.065442
# 42                                           ['Zara']     35-44     -0.043726
# 46                                           ['Zara']     35-44     -0.096598
# 40                                           ['Zara']     18-24     -0.041397
# 28         ['Allen Solly', 'Gucci', "Levi's", 'Zara']     18-24      0.218600
# 31                                           ['Zara']     35-44      0.191615
# 38                                  ['Gucci', 'Zara']     35-44     -0.017999
# 23                                           ['Zara']     18-24      0.465744
# 22                                            ['H&M']     25-34      0.525370
# 26                                  ['Gucci', 'Zara']     18-24      0.252473
# 44                                           ['Zara']     25-34     -0.069644
# 30       ['Adidas', 'Under Armour', 'Reebok', 'Puma']     35-44      0.205006
# 41                            ['Allen Solly', 'Zara']     18-24     -0.042938
# 49                                            ['H&M']     35-44     -0.229296
# 29                                           ['Zara']     25-34      0.207253
# 12                                         ["Levi's"]     25-34      0.813948
# 20                            ['Zara', 'Allen Solly']     18-24      0.612009
# 45                                 ["Levi's", 'Zara']     25-34     -0.092572
# 48                                           ['Zara']     18-24     -0.164623
# 47                                            ['H&M']     25-34     -0.161645
# 32                                         ["Levi's"]     25-34      0.181246
# 39                            ['Zara', 'Allen Solly']     18-24     -0.023907
# 35                                           ['Zara']     18-24      0.095997
# 24                                           ['Zara']     35-44      0.431399
#
#     brand_fit_score  final_score
# 2          6.646884     2.882428
# 0          5.700417     2.861303
# 1          6.206927     2.794890
# 13         7.217283     2.702092
# 16         7.106203     2.597548
# 4          6.112656     2.488104
# 8          6.104064     2.447581
# 5          4.650647     2.047855
# 36         6.591403     2.033241
# 14         5.113707     2.018154
# 10         4.046381     1.793647
# 11         4.005040     1.773791
# 25         5.137569     1.733677
# 34         5.486454     1.726467
# 15         4.147315     1.722498
# 7          3.485094     1.678298
# 19         4.135610     1.674309
# 9          3.510972     1.665415
# 18         4.057408     1.662839
# 21         4.146250     1.643327
# 33         4.842790     1.539236
# 27         4.546026     1.534835
# 37         4.997302     1.529890
# 3          2.782280     1.522984
# 17         3.436094     1.480816
# 6          2.643631     1.432025
# 43         4.627552     1.342456
# 42         4.519613     1.325275
# 46         4.612496     1.316130
# 40         4.428714     1.299636
# 28         3.546484     1.216965
# 31         3.525410     1.191754
# 38         3.919685     1.163307
# 23         2.740913     1.148294
# 22         2.524072     1.124980
# 26         3.157867     1.124091
# 44         3.686489     1.057196
# 30         3.037794     1.054842
# 41         3.559104     1.037674
# 49         3.991219     1.036859
# 29         2.934281     1.025361
# 12         1.487475     1.016006
# 20         1.710397     0.941525
# 45         3.047492     0.849447
# 48         2.881878     0.749327
# 47         2.775701     0.719559
# 32         1.908635     0.699463
# 39         2.374723     0.695682
# 35         1.961526     0.655656
# 24         0.771456     0.533416
